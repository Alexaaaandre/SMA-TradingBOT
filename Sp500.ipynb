# %%
import pandas as pd
import os 
import numpy as np
import pandas_ta as ta
import plotly.graph_objects as go

# %%
df = pd.read_csv(r"C:\Users\alrem\Desktop\données EURUSD\spy.csv")

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close
# 0     2013-11-06  177.029999  177.500000  176.539993  177.169998  147.667892  \
# 1     2013-11-07  177.500000  177.639999  174.759995  174.929993  145.800873
# 2     2013-11-08  174.869995  177.309998  174.850006  177.289993  147.767944
# 3     2013-11-11  177.119995  177.529999  176.910004  177.320007  147.792877
# 4     2013-11-12  176.940002  177.360001  176.369995  176.960007  147.492889
# ...          ...         ...         ...         ...         ...         ...
# 2511  2023-10-30  413.559998  416.679993  412.220001  415.589996  415.589996
# 2512  2023-10-31  416.179993  418.529999  414.209991  418.200012  418.200012
# 2513  2023-11-01  419.200012  423.500000  418.649994  422.660004  422.660004
# 2514  2023-11-02  426.579987  430.920013  426.559998  430.760010  430.760010
# 2515  2023-11-03  433.140015  436.290009  433.010010  434.690002  434.690002
#
#          Volume
# 0      87348000
# ...

# %%
df=df[df['Volume']!=0]

# %%
df['EMA'] = ta.ema(df.Close, length=150)
df['SMA'] = ta.sma(df.Close, length=150)

# %%
df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close
# 2511  2023-10-30  413.559998  416.679993  412.220001  415.589996  415.589996  \
# 2512  2023-10-31  416.179993  418.529999  414.209991  418.200012  418.200012
# 2513  2023-11-01  419.200012  423.500000  418.649994  422.660004  422.660004
# 2514  2023-11-02  426.579987  430.920013  426.559998  430.760010  430.760010
# 2515  2023-11-03  433.140015  436.290009  433.010010  434.690002  434.690002
#
#          Volume         EMA         SMA
# 2511   86562700  428.693295  427.652667
# 2512   79665200  428.554311  426.835668
# 2513   98068100  428.476241  426.303001
# 2514   94938900  428.506489  426.282001
# 2515  100110800  428.588390  426.424334

# %%
df.tail(150)
# Out:
#             Date        Open        High         Low       Close   Adj Close
# 2366  2023-04-03  408.850006  411.369995  408.440002  410.950012  407.990021  \
# 2367  2023-04-04  411.619995  411.920013  407.239990  408.670013  405.726440
# 2368  2023-04-05  407.910004  408.700012  405.880005  407.600006  404.664154
# 2369  2023-04-06  406.769989  409.480011  405.679993  409.190002  406.242676
# 2370  2023-04-10  406.609985  409.690002  405.970001  409.609985  406.659637
# ...          ...         ...         ...         ...         ...         ...
# 2511  2023-10-30  413.559998  416.679993  412.220001  415.589996  415.589996
# 2512  2023-10-31  416.179993  418.529999  414.209991  418.200012  418.200012
# 2513  2023-11-01  419.200012  423.500000  418.649994  422.660004  422.660004
# 2514  2023-11-02  426.579987  430.920013  426.559998  430.760010  430.760010
# 2515  2023-11-03  433.140015  436.290009  433.010010  434.690002  434.690002
#
#          Volume         EMA         SMA
# ...

# %%
df=df[["Close","EMA","SMA"]]

# %%
df= df.tail(210)

# %%
df
# Out:
#            Close         EMA         SMA
# 2366  410.950012  397.470463  390.845800
# 2367  408.670013  397.618801  390.886067
# 2368  407.600006  397.751002  390.948667
# 2369  409.190002  397.902512  391.042067
# 2370  409.609985  398.057578  391.130000
# ...          ...         ...         ...
# 2511  415.589996  428.693295  430.649201
# 2512  418.200012  428.554311  430.799868
# 2513  422.660004  428.476241  430.941934
# 2514  430.760010  428.506489  431.122334
# 2515  434.690002  428.588390  431.291001
#
# [150 rows x 3 columns]

# %%
fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])

# %%
df['SMA_30'] = df['Close'].rolling(window=30).mean()
df['SMA_50'] = df['Close'].rolling(window=50).mean()
df['SMA_200'] = df['Close'].rolling(window=200).mean()

# %%
fig.add_trace(go.Scatter(x=df['Date'], y=df['SMA_30'], mode='lines', name='SMA 30'))
fig.add_trace(go.Scatter(x=df['Date'], y=df['SMA_50'], mode='lines', name='SMA 50'))
fig.add_trace(go.Scatter(x=df['Date'], y=df['SMA_200'], mode='lines', name='SMA 200'))
